# %%
import os
import json
import pandas as pd
import numpy as np

# %%
def flatten_json_concatenated(json_obj, prefix=''):
    """
    Recursively flattens a JSON object into a dictionary and concatenates hierarchy field names
    """
    flat_dict = {}
    if isinstance(json_obj, dict):
        for key, value in json_obj.items():
            new_prefix = prefix + key + '_' if prefix else key + '_'
            flat_dict.update(flatten_json_concatenated(value, new_prefix))
    elif isinstance(json_obj, list):
        for i in range(len(json_obj)):
            flat_dict.update(flatten_json_concatenated(json_obj[i], prefix))
    else:
        flat_dict[prefix[:-1]] = json_obj
    return flat_dict

# %%
def read_json_files_in_directory(directory_path):
    """
    Reads all JSON files in a directory and returns a dictionary where the file name without extension is the key and the value is the JSON data
    """
    json_data_dict = {}
    for filename in os.listdir(directory_path):
        if filename.endswith(".json"):
            file_path = os.path.join(directory_path, filename)
            with open(file_path, "r") as f:
                json_data = json.load(f)
                key = os.path.splitext(filename)[0]
                json_data_dict[key] = json_data
    return json_data_dict

# %%
json_file_objects = read_json_files_in_directory(r'C:\Users\aghor\OneDrive\Documents\GitHub\congress_resume\resumes')

df = pd.DataFrame()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

for json_file_name, json_file_obj in json_file_objects.items():
    file_dict = flatten_json_concatenated(json_file_obj)
    file_series = pd.Series(file_dict, name=json_file_name)
    df = pd.concat([df, file_series], axis=1)
    
df = df.T

# %%
df.head(2)
# Out:
#                                                      url  \
# 100_1  https://www.senate.gov/reference/resources/pdf...
# 100_2  https://www.senate.gov/reference/resources/pdf...
#
#                    created_date congress session               report_date  \
# 100_1  2023-03-19T08:00:00.000Z      100       1  1988-11-10T05:00:00.000Z
# 100_2  2023-03-19T08:00:00.000Z      100       2  1988-11-10T05:00:00.000Z
#
#       legislative_activity_start_date legislative_activity_end_date  \
# 100_1        1987-01-06T05:00:00.000Z      1987-12-22T05:00:00.000Z
# 100_2        1988-01-25T05:00:00.000Z      1988-10-22T05:00:00.000Z
#
#       legislative_activity_senate_days_in_session  \
# 100_1                                         170
# 100_2                                         137
#
#       legislative_activity_senate_time_in_session  \
# 100_1                                   P1214M52S
# 100_2                                  PT1126H52M
#
#       legislative_activity_senate_congressional_record_pages_of_proceedings  \
# 100_1                                              18660
# 100_2                                              17397
#
#       legislative_activity_senate_public_bills_enacted_into_law  \
# 100_1                                                 96
# 100_2                                                193
#
#       legislative_activity_senate_private_bills_enacted_into_law  \
# 100_1                                                  2
# 100_2                                                 10
#
#       legislative_activity_senate_bills_in_conference  \
# 100_1                                               6
# 100_2                                               3
#
#       legislative_activity_senate_measures_passed_total_total  \
# 100_1                                                616
# 100_2                                                814
#
#       legislative_activity_senate_measures_passed_total_senate_bills  \
# 100_1                                                110
# 100_2                                                188
#
#       legislative_activity_senate_measures_passed_total_house_bills  \
# 100_1                                                135
# 100_2                                                273
#
#       legislative_activity_senate_measures_passed_total_senate_joint_resolutions  \
# 100_1                                                 91
# 100_2                                                106
#
#       legislative_activity_senate_measures_passed_total_house_joint_resolutions  \
# 100_1                                                 48
# 100_2                                                 51
#
#       legislative_activity_senate_measures_passed_total_senate_concurrent_resolutions  \
# 100_1                                                 25
# 100_2                                                 52
#
#       legislative_activity_senate_measures_passed_total_house_concurrent_resolutions  \
# 100_1                                                 31
# 100_2                                                 32
#
#       legislative_activity_senate_measures_passed_total_simple_resolutions  \
# 100_1                                                176
# 100_2                                                112
#
#       legislative_activity_senate_measures_reported_total_total  \
# 100_1                                                398
# 100_2                                                511
#
#       legislative_activity_senate_measures_reported_total_senate_bills  \
# 100_1                                                183
# 100_2                                                262
#
#       legislative_activity_senate_measures_reported_total_house_bills  \
# 100_1                                                 59
# 100_2                                                100
#
#       legislative_activity_senate_measures_reported_total_senate_joint_resolutions  \
# 100_1                                                 72
# 100_2                                                 88
#
#       legislative_activity_senate_measures_reported_total_house_joint_resolutions  \
# 100_1                                                  6
# 100_2                                                  3
#
#       legislative_activity_senate_measures_reported_total_senate_concurrent_resolutions  \
# 100_1                                                 11
# 100_2                                                 14
#
#       legislative_activity_senate_measures_reported_total_house_concurrent_resolutions  \
# 100_1                                                  5
# 100_2                                                  1
#
#       legislative_activity_senate_measures_reported_total_simple_resolutions  \
# 100_1                                                 62
# 100_2                                                 43
#
#       legislative_activity_senate_special_reports  \
# 100_1                                          28
# 100_2                                          13
#
#       legislative_activity_senate_conference_reports  \
# 100_1                                              1
# 100_2                                            NaN
#
#       legislative_activity_senate_measures_pending_on_calendar  \
# 100_1                                                 76
# 100_2                                                108
#
#       legislative_activity_senate_measures_introduced_total_total  \
# 100_1                                               2685
# 100_2                                               1328
#
#       legislative_activity_senate_measures_introduced_total_bills  \
# 100_1                                               1998
# 100_2                                                932
#
#       legislative_activity_senate_measures_introduced_total_joint_resolutions  \
# 100_1                                                239
# 100_2                                                156
#
#       legislative_activity_senate_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                 95
# 100_2                                                 74
#
#       legislative_activity_senate_measures_introduced_total_simple_resolutions  \
# 100_1                                                353
# 100_2                                                166
#
#       legislative_activity_senate_quorum_calls  \
# 100_1                                       36
# 100_2                                       26
#
#       legislative_activity_senate_yea_and_nay_votes  \
# 100_1                                           420
# 100_2                                           379
#
#       legislative_activity_senate_bills_vetoed  \
# 100_1                                        1
# 100_2                                        6
#
#       legislative_activity_senate_vetoes_overridden  \
# 100_1                                             2
# 100_2                                             1
#
#       legislative_activity_house_days_in_session  \
# 100_1                                        169
# 100_2                                        129
#
#       legislative_activity_house_time_in_session  \
# 100_1                                  PT909H57M
# 100_2                                  PT749H01M
#
#       legislative_activity_house_congressional_record_pages_of_proceedings  \
# 100_1                                              13078
# 100_2                                              11290
#
#       legislative_activity_house_public_bills_enacted_into_law  \
# 100_1                                                144
# 100_2                                                280
#
#       legislative_activity_house_private_bills_enacted_into_law  \
# 100_1                                                  5
# 100_2                                                 31
#
#       legislative_activity_house_bills_in_conference  \
# 100_1                                             15
# 100_2                                              4
#
#       legislative_activity_house_measures_passed_total_total  \
# 100_1                                                644
# 100_2                                                858
#
#       legislative_activity_house_measures_passed_total_senate_bills  \
# 100_1                                                 44
# 100_2                                                131
#
#       legislative_activity_house_measures_passed_total_house_bills  \
# 100_1                                                272
# 100_2                                                330
#
#       legislative_activity_house_measures_passed_total_senate_joint_resolutions  \
# 100_1                                                 63
# 100_2                                                 85
#
#       legislative_activity_house_measures_passed_total_house_joint_resolutions  \
# 100_1                                                 66
# 100_2                                                 70
#
#       legislative_activity_house_measures_passed_total_senate_concurrent_resolutions  \
# 100_1                                                  8
# 100_2                                                 32
#
#       legislative_activity_house_measures_passed_total_house_concurrent_resolutions  \
# 100_1                                                 53
# 100_2                                                 46
#
#       legislative_activity_house_measures_passed_total_simple_resolutions  \
# 100_1                                                138
# 100_2                                                164
#
#       legislative_activity_house_measures_reported_total_total  \
# 100_1                                                426
# 100_2                                                636
#
#       legislative_activity_house_measures_reported_total_senate_bills  \
# 100_1                                                  9
# 100_2                                                 34
#
#       legislative_activity_house_measures_reported_total_house_bills  \
# 100_1                                                299
# 100_2                                                360
#
#       legislative_activity_house_measures_reported_total_house_joint_resolutions  \
# 100_1                                                  9
# 100_2                                                  5
#
#       legislative_activity_house_measures_reported_total_house_concurrent_resolutions  \
# 100_1                                                  7
# 100_2                                                  5
#
#       legislative_activity_house_measures_reported_total_simple_resolutions  \
# 100_1                                                102
# 100_2                                                 95
#
#       legislative_activity_house_special_reports  \
# 100_1                                         56
# 100_2                                         85
#
#       legislative_activity_house_conference_reports  \
# 100_1                                            16
# 100_2                                            49
#
#       legislative_activity_house_measures_pending_on_calendar  \
# 100_1                                                 48
# 100_2                                                 88
#
#       legislative_activity_house_measures_introduced_total_total  \
# 100_1                                               4857
# 100_2                                                  2
#
#       legislative_activity_house_measures_introduced_total_bills  \
# 100_1                                               3840
# 100_2                                                  1
#
#       legislative_activity_house_measures_introduced_total_joint_resolutions  \
# 100_1                                                437
# 100_2                                                241
#
#       legislative_activity_house_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                235
# 100_2                                                163
#
#       legislative_activity_house_measures_introduced_total_simple_resolutions  \
# 100_1                                                345
# 100_2                                                263
#
#       legislative_activity_house_quorum_calls  \
# 100_1                                      23
# 100_2                                      14
#
#       legislative_activity_house_yea_and_nay_votes  \
# 100_1                                          234
# 100_2                                          308
#
#       legislative_activity_house_recorded_votes  \
# 100_1                                       254
# 100_2                                       143
#
#       legislative_activity_house_bills_vetoed  \
# 100_1                                       2
# 100_2                                      10
#
#       legislative_activity_house_vetoes_overridden  \
# 100_1                                            2
# 100_2                                            1
#
#       legislative_activity_total_congressional_record_pages_of_proceedings  \
# 100_1                                              31738
# 100_2                                              28687
#
#       legislative_activity_total_congressional_record_extensions_of_remarks  \
# 100_1                                               5016
# 100_2                                               3776
#
#       legislative_activity_total_public_bills_enacted_into_law  \
# 100_1                                                240
# 100_2                                                NaN
#
#       legislative_activity_total_private_bills_enacted_into_law  \
# 100_1                                                  7
# 100_2                                                NaN
#
#       legislative_activity_total_measures_passed_total_total  \
# 100_1                                               1260
# 100_2                                               1672
#
#       legislative_activity_total_measures_reported_total_total  \
# 100_1                                                824
# 100_2                                               1147
#
#       legislative_activity_total_measures_introduced_total_total  \
# 100_1                                               7542
# 100_2                                               3740
#
#       legislative_activity_total_bills_vetoed  \
# 100_1                                       3
# 100_2                                      16
#
#       disposition_of_executive_nominations_start_date  \
# 100_1                        1987-01-06T05:00:00.000Z
# 100_2                        1988-01-25T05:00:00.000Z
#
#       disposition_of_executive_nominations_end_date  \
# 100_1                      1988-10-22T05:00:00.000Z
# 100_2                      1988-10-22T05:00:00.000Z
#
#       disposition_of_executive_nominations_civilian_nominees_total  \
# 100_1                                                470
# 100_2                                                516
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_confirmed  \
# 100_1                                                331
# 100_2                                                335
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_unconfirmed  \
# 100_1                                                112
# 100_2                                                170
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_withdrawn  \
# 100_1                                                 10
# 100_2                                                 11
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_rejected  \
# 100_1                                                  1
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_to_white_house_1  \
# 100_1                                                  7
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_to_white_house_2  \
# 100_1                                                  9
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_total  \
# 100_1                                               4248
# 100_2                                               2276
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_confirmed  \
# 100_1                                               4238
# 100_2                                               2022
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_unconfirmed  \
# 100_1                                                 10
# 100_2                                                254
#
#       disposition_of_executive_nominations_air_force_nominees_total  \
# 100_1                                              18667
# 100_2                                              15304
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_confirmed  \
# 100_1                                              15711
# 100_2                                              15304
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_unconfirmed  \
# 100_1                                               2955
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_returned_to_white_house  \
# 100_1                                                  1
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_army_nominees_total  \
# 100_1                                              14448
# 100_2                                              12861
#
#       disposition_of_executive_nominations_army_nominees_disposition_confirmed  \
# 100_1                                              12086
# 100_2                                              12858
#
#       disposition_of_executive_nominations_army_nominees_disposition_unconfirmed  \
# 100_1                                               2361
# 100_2                                                  1
#
#       disposition_of_executive_nominations_army_nominees_disposition_returned_to_white_house  \
# 100_1                                                  1
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_navy_nominees_total  \
# 100_1                                              12101
# 100_2                                              10205
#
#       disposition_of_executive_nominations_navy_nominees_disposition_confirmed  \
# 100_1                                              12055
# 100_2                                              10203
#
#       disposition_of_executive_nominations_navy_nominees_disposition_unconfirmed  \
# 100_1                                                 46
# 100_2                                                  1
#
#       disposition_of_executive_nominations_marine_corps_nominees_total  \
# 100_1                                               1995
# 100_2                                               1596
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_confirmed  \
# 100_1                                               1983
# 100_2                                               1595
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_unconfirmed  \
# 100_1                                                 10
# 100_2                                                  1
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_returned_to_white_house  \
# 100_1                                                  2
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_nominees_received_this_session  \
# 100_1                                              51929
# 100_2                                              37264
#
#       disposition_of_executive_nominations_summary_total_confirmed  \
# 100_1                                              46404
# 100_2                                              42317
#
#       disposition_of_executive_nominations_summary_total_unconfirmed  \
# 100_1                                               5494
# 100_2                                                428
#
#       disposition_of_executive_nominations_summary_total_withdrawn  \
# 100_1                                                 10
# 100_2                                                 13
#
#       disposition_of_executive_nominations_summary_total_rejected  \
# 100_1                                                  1
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_returned_to_white_house  \
# 100_1                                                 20
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.senate.measures_reported_total.total  \
# 100_1  These figures on measures reported include all...
# 100_2  These figures on measures reported include all...
#
#       footnote_resume.legislative_activity.house.measures_reported_total.total  \
# 100_1  These figures on measures reported include all...
# 100_2  These figures on measures reported include all...
#
#       footnote_resume.disposition_of_executive_nominations.civilian_nominees.disposition.returned_to_white_house_1  \
# 100_1  Nominations returned to the President without ...
# 100_2                                                NaN
#
#       footnote_resume.disposition_of_executive_nominations.civilian_nominees.disposition.returned_to_white_house_2  \
# 100_1  Nominations returned to the President without ...
# 100_2                                                NaN
#
#       legislative_activity_house_measures_reported_total_senate_joint_resolutions  \
# 100_1                                                NaN
# 100_2                                                  2
#
#       legislative_activity_house_measures_reported_total_senate_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                  1
#
#       legislative_activity_house_measures_introduced_total_field1  \
# 100_1                                                NaN
# 100_2                                                412
#
#       legislative_activity_house_measures_introduced_total_field2  \
# 100_1                                                NaN
# 100_2                                                745
#
#       disposition_of_executive_nominations_civilian_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                                112
#
#       disposition_of_executive_nominations_other_civilian_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                                 10
#
#       disposition_of_executive_nominations_air_force_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                               2955
#
#       disposition_of_executive_nominations_army_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                               2361
#
#       disposition_of_executive_nominations_army_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                  2
#
#       disposition_of_executive_nominations_navy_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                                 46
#
#       disposition_of_executive_nominations_navy_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                  1
#
#       disposition_of_executive_nominations_marine_corps_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                                 10
#
#       disposition_of_executive_nominations_summary_total_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                               5494
#
#       legislative_activity_house_congressional_record_extensions_of_remarks  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_congressional_record_extensions_of_remarks  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_bills_through_conference  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_bills_through_conference  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_bills_not_signed  \
# 100_1                                          NaN
# 100_2                                          NaN
#
#       legislative_activity_total_bills_in_conference  \
# 100_1                                            NaN
# 100_2                                            NaN
#
#       legislative_activity_total_bills_not_signed  \
# 100_1                                         NaN
# 100_2                                         NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_ajournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.senate.bills_not_signed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_returned_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_measures_reported_total_sentate_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_return_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_navy_nominees_disposition_return_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_navy_nominees_disposition_returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_recorded_votes  \
# 100_1                                        NaN
# 100_2                                        NaN
#
#       legislative_activity_senate_measures_reported_total_senate _concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_bill_in_conference  \
# 100_1                                            NaN
# 100_2                                            NaN
#
#       legislative_activity_total_public_bill_enacted_into_law  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_measures_introduced_total_quorum_calls  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_measures_introduced_total_yea_and_nay_votes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_measures_introduced_total_recorded_votes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_measures_introduced_total_bills_vetoed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_measures_introduced_total_vetoes_overridden  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_uncomfirmed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_space_force_nominees_total  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_space_force_nominees_disposition_confirmed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_public_bills_enacted_into_law_total  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_space_force_nominees_disposition_unconfirmed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_space_force_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_space_force_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_reported_measures_not_acted_on  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_bills_vetoed_total  \
# 100_1                                            NaN
# 100_2                                            NaN
#
#       legislative_activity_senate_bills_vetoed_regular_vetoes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_bills_vetoed_pocket_vetoes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_reported_measures_not_acted_on  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_bills_vetoed_total  \
# 100_1                                           NaN
# 100_2                                           NaN
#
#       legislative_activity_house_bills_vetoed_regular_vetoes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_house_bills_vetoed_pocket_vetoes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_congressional_record_appendix  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_bill_in_conference  \
# 100_1                                           NaN
# 100_2                                           NaN
#
#       legislative_activity_total_bills_through_conference  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_measures_passed_total_simple_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_measures_reported_total_simple_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_conference_reports  \
# 100_1                                           NaN
# 100_2                                           NaN
#
#       legislative_activity_total_measures_introduced_total_bills  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_measures_introduced_total_joint_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_measures_introduced_total_simple_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_quorum_calls  \
# 100_1                                     NaN
# 100_2                                     NaN
#
#       legislative_activity_total_yea_and_nay_votes  \
# 100_1                                          NaN
# 100_2                                          NaN
#
#       legislative_activity_total_bills_vetoed_total  \
# 100_1                                           NaN
# 100_2                                           NaN
#
#       legislative_activity_total_bills_vetoed_regular_vetoes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_bills_vetoed_pocket_vetoes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_vetoes_overridden  \
# 100_1                                          NaN
# 100_2                                          NaN
#
#       disposition_of_executive_nominations_postmaster_nominees_total  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_postmaster_nominees_disposition_confirmed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_postmaster_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_postmaster_nominees_disposition_unconfirmed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.senate.reported_measures_not_acted_on  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.house.reported_measures_not_acted_on  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_senate_regular_vetoes  \
# 100_1                                        NaN
# 100_2                                        NaN
#
#       legislative_activity_senate_pocket_vetoes  \
# 100_1                                       NaN
# 100_2                                       NaN
#
#       legislative_activity_house_regular_vetoes  \
# 100_1                                       NaN
# 100_2                                       NaN
#
#       legislative_activity_house_pocket_vetoes  \
# 100_1                                      NaN
# 100_2                                      NaN
#
#       legislative_activity_total_regular_vetoes  \
# 100_1                                       NaN
# 100_2                                       NaN
#
#       legislative_activity_total_pocket_vetoes  \
# 100_1                                      NaN
# 100_2                                      NaN
#
#       legislative_activity_senate_measures_passed_total_bills  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_total_measures_passed_total_senate_bills  \
# 100_1                                                NaN
# 100_2                                                NaN
#
# ...
# 100_1                            NaN                               NaN
# 100_2                            NaN                               NaN
#
#       house_measures_passed_total_senate_bills  \
# 100_1                                      NaN
# 100_2                                      NaN
#
#       house_measures_passed_total_house_bills  \
# 100_1                                     NaN
# 100_2                                     NaN
#
#       house_measures_passed_total_senate_joint_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_passed_total_house_joint_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_passed_total_senate_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_passed_total_house_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_passed_total_simple_resolutions  \
# 100_1                                            NaN
# 100_2                                            NaN
#
#       house_measures_reported_total_total  \
# 100_1                                 NaN
# 100_2                                 NaN
#
#       house_measures_reported_total_senate_bills  \
# 100_1                                        NaN
# 100_2                                        NaN
#
#       house_measures_reported_total_house_bills  \
# 100_1                                       NaN
# 100_2                                       NaN
#
#       house_measures_reported_total_senate_joint_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_reported_total_house_joint_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_reported_total_senate_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_reported_total_house_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_reported_total_simple_resolutions house_special_reports  \
# 100_1                                              NaN                   NaN
# 100_2                                              NaN                   NaN
#
#       house_reported_measures_not_acted_on  \
# 100_1                                  NaN
# 100_2                                  NaN
#
#       house_measures_introduced_total_total  \
# 100_1                                   NaN
# 100_2                                   NaN
#
#       house_measures_introduced_total_bills  \
# 100_1                                   NaN
# 100_2                                   NaN
#
#       house_measures_introduced_total_joint_resolutions  \
# 100_1                                               NaN
# 100_2                                               NaN
#
#       house_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       house_measures_introduced_total_simple_resolutions house_quorum_calls  \
# 100_1                                                NaN                NaN
# 100_2                                                NaN                NaN
#
#       house_yea_and_nay_votes house_bills_vetoed  \
# 100_1                     NaN                NaN
# 100_2                     NaN                NaN
#
#       total_congressional_record_pages_of_proceedings  \
# 100_1                                             NaN
# 100_2                                             NaN
#
#       total_congressional_record_appendix total_public_bills_enacted_into_law  \
# 100_1                                 NaN                                 NaN
# 100_2                                 NaN                                 NaN
#
#       total_private_bills_enacted_into_law  \
# 100_1                                  NaN
# 100_2                                  NaN
#
#       total_measures_passed_total_simple_resolutions  \
# 100_1                                            NaN
# 100_2                                            NaN
#
#       total_measures_reported_total_simple_resolutions  \
# 100_1                                              NaN
# 100_2                                              NaN
#
#       total_measures_introduced_total_total  \
# 100_1                                   NaN
# 100_2                                   NaN
#
#       total_measures_introduced_total_bills  \
# 100_1                                   NaN
# 100_2                                   NaN
#
#       total_measures_introduced_total_joint_resolutions  \
# 100_1                                               NaN
# 100_2                                               NaN
#
#       total_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       total_measures_introduced_total_simple_resolutions total_quorum_calls  \
# 100_1                                                NaN                NaN
# 100_2                                                NaN                NaN
#
#       total_yea_and_nay_votes  \
# 100_1                     NaN
# 100_2                     NaN
#
#       legislative_activity_total_reported_measures_not_acted_on  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.senate.quorum_calls  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.senate.yea_and_nay_votes  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.army_nominees.disposition.returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.navy_nominees.disposition.returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.civilian_nominees.disposition.returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.summary.total_returned_to_white_house  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.disposition_of_executive_nominations.civilian_nominees.disposition.unconfirmed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       footnote_resume.disposition_of_executive_nominations.summary.total_nominees_received_this_session  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_congressional_record_pages_of_proceedings  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_congressional_record_extensions_of_remarks  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_public_bills_enacted_into_law  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_private_bills_enacted_into_law  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       legislative_activity_bills_in_conference  \
# 100_1                                      NaN
# 100_2                                      NaN
#
#       legislative_activity_bills_through_conference  \
# 100_1                                           NaN
# 100_2                                           NaN
#
#       legislative_activity_house_start_date  \
# 100_1                                   NaN
# 100_2                                   NaN
#
#       legislative_activity_house_end_date  \
# 100_1                                 NaN
# 100_2                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_superseded_by_renominations_confirmations  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_of_confirmation_ontime  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_of_confirmation_ontime  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_superseded_by_renominations_confirmations  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_failed_at_first_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_failed_at_second_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_failed  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_first_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_second_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_first_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_second_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_recess_appointments  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_recess_appointments  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_of_confirmation_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_of_confirmation_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_superceded_by_recess_appointment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_of_confirmation_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_failed_of_confirmation_at_sine_die_adjournment  \
# 100_1                                                NaN
# 100_2                                                NaN
#
#       disposition_of_executive_nominations_summary_total_superseded_by_recess_appointment
# 100_1                                                NaN
# 100_2                                                NaN

# %%
for index in df.index:
    print(index)
print(df.index[0])
# Out:
# 100_1
# 100_2
# 101_1
# 101_2
# 102_1
# 102_2
# 103_1
# 103_2
# 104_1
# 104_2
# 105_1
# 105_2
# 106_1
# 106_2
# 107_1
# 107_2
# 108_1
# 108_2
# 109_1
# 109_2
# 110_1
# 110_2
# 111_1
# 111_2
# 112_1
# 112_2
# 113_1
# 113_2
# 114_1
# 114_2
# 115_1
# 115_2
# 116_1
# 116_2
# 117_1
# 117_2
# 80_1
# 80_2
# 81_1
# 81_2
# 82_1
# 82_2
# 83_1
# 83_2
# 84_1
# 84_2
# 85_1
# 85_2
# 86_1
# 86_2
# 87_1
# 87_2
# 88_1
# 88_2
# 89_1
# 89_2
# 90_1
# 90_2
# 91_1
# 91_2
# 92_1
# 92_2
# 93_1
# 93_2
# 94_1
# 94_2
# 95_1
# 95_2
# 96_1
# 96_2
# 97_1
# 97_2
# 98_1
# 98_2
# 99_1
# 99_2
# 100_1

# %%
df.loc[['100_1', '80_1']]
# Out:
#                                                      url  \
# 100_1  https://www.senate.gov/reference/resources/pdf...
# 80_1   https://www.senate.gov/reference/resources/pdf...
#
#                    created_date congress session               report_date  \
# 100_1  2023-03-19T08:00:00.000Z      100       1  1988-11-10T05:00:00.000Z
# 80_1   2023-03-19T08:00:00.000Z       80       1                       NaN
#
#       legislative_activity_start_date legislative_activity_end_date  \
# 100_1        1987-01-06T05:00:00.000Z      1987-12-22T05:00:00.000Z
# 80_1         1947-01-03T05:00:00.000Z      1947-12-19T05:00:00.000Z
#
#       legislative_activity_senate_days_in_session  \
# 100_1                                         170
# 80_1                                          143
#
#       legislative_activity_senate_time_in_session  \
# 100_1                                   P1214M52S
# 80_1                                    PT807H36M
#
#       legislative_activity_senate_congressional_record_pages_of_proceedings  \
# 100_1                                              18660
# 80_1                                                6150
#
#       legislative_activity_senate_public_bills_enacted_into_law  \
# 100_1                                                 96
# 80_1                                                 120
#
#       legislative_activity_senate_private_bills_enacted_into_law  \
# 100_1                                                  2
# 80_1                                                  37
#
#       legislative_activity_senate_bills_in_conference  \
# 100_1                                               6
# 80_1                                              NaN
#
#       legislative_activity_senate_measures_passed_total_total  \
# 100_1                                                616
# 80_1                                                 841
#
#       legislative_activity_senate_measures_passed_total_senate_bills  \
# 100_1                                                110
# 80_1                                                 278
#
#       legislative_activity_senate_measures_passed_total_house_bills  \
# 100_1                                                135
# 80_1                                                 138
#
#       legislative_activity_senate_measures_passed_total_senate_joint_resolutions  \
# 100_1                                                 91
# 80_1                                                  47
#
#       legislative_activity_senate_measures_passed_total_house_joint_resolutions  \
# 100_1                                                 48
# 80_1                                                  30
#
#       legislative_activity_senate_measures_passed_total_senate_concurrent_resolutions  \
# 100_1                                                 25
# 80_1                                                  12
#
#       legislative_activity_senate_measures_passed_total_house_concurrent_resolutions  \
# 100_1                                                 31
# 80_1                                                  19
#
#       legislative_activity_senate_measures_passed_total_simple_resolutions  \
# 100_1                                                176
# 80_1                                                  87
#
#       legislative_activity_senate_measures_reported_total_total  \
# 100_1                                                398
# 80_1                                                 973
#
#       legislative_activity_senate_measures_reported_total_senate_bills  \
# 100_1                                                183
# 80_1                                                 357
#
#       legislative_activity_senate_measures_reported_total_house_bills  \
# 100_1                                                 59
# 80_1                                                 401
#
#       legislative_activity_senate_measures_reported_total_senate_joint_resolutions  \
# 100_1                                                 72
# 80_1                                                  53
#
#       legislative_activity_senate_measures_reported_total_house_joint_resolutions  \
# 100_1                                                  6
# 80_1                                                  31
#
#       legislative_activity_senate_measures_reported_total_senate_concurrent_resolutions  \
# 100_1                                                 11
# 80_1                                                  16
#
#       legislative_activity_senate_measures_reported_total_house_concurrent_resolutions  \
# 100_1                                                  5
# 80_1                                                  20
#
#       legislative_activity_senate_measures_reported_total_simple_resolutions  \
# 100_1                                                 62
# 80_1                                                  95
#
#       legislative_activity_senate_special_reports  \
# 100_1                                          28
# 80_1                                           21
#
#       legislative_activity_senate_conference_reports  \
# 100_1                                              1
# 80_1                                             NaN
#
#       legislative_activity_senate_measures_pending_on_calendar  \
# 100_1                                                 76
# 80_1                                                 NaN
#
#       legislative_activity_senate_measures_introduced_total_total  \
# 100_1                                               2685
# 80_1                                                2312
#
#       legislative_activity_senate_measures_introduced_total_bills  \
# 100_1                                               1998
# 80_1                                                1924
#
#       legislative_activity_senate_measures_introduced_total_joint_resolutions  \
# 100_1                                                239
# 80_1                                                 170
#
#       legislative_activity_senate_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                 95
# 80_1                                                  37
#
#       legislative_activity_senate_measures_introduced_total_simple_resolutions  \
# 100_1                                                353
# 80_1                                                 181
#
#       legislative_activity_senate_quorum_calls  \
# 100_1                                       36
# 80_1                                       332
#
#       legislative_activity_senate_yea_and_nay_votes  \
# 100_1                                           420
# 80_1                                            138
#
#       legislative_activity_senate_bills_vetoed  \
# 100_1                                        1
# 80_1                                       NaN
#
#       legislative_activity_senate_vetoes_overridden  \
# 100_1                                             2
# 80_1                                            NaN
#
#       legislative_activity_house_days_in_session  \
# 100_1                                        169
# 80_1                                         144
#
#       legislative_activity_house_time_in_session  \
# 100_1                                  PT909H57M
# 80_1                                    PT686H2M
#
#       legislative_activity_house_congressional_record_pages_of_proceedings  \
# 100_1                                              13078
# 80_1                                                5379
#
#       legislative_activity_house_public_bills_enacted_into_law  \
# 100_1                                                144
# 80_1                                                 275
#
#       legislative_activity_house_private_bills_enacted_into_law  \
# 100_1                                                  5
# 80_1                                                  94
#
#       legislative_activity_house_bills_in_conference  \
# 100_1                                             15
# 80_1                                             NaN
#
#       legislative_activity_house_measures_passed_total_total  \
# 100_1                                                644
# 80_1                                                1029
#
#       legislative_activity_house_measures_passed_total_senate_bills  \
# 100_1                                                 44
# 80_1                                                 138
#
#       legislative_activity_house_measures_passed_total_house_bills  \
# 100_1                                                272
# 80_1                                                 568
#
#       legislative_activity_house_measures_passed_total_senate_joint_resolutions  \
# 100_1                                                 63
# 80_1                                                  29
#
#       legislative_activity_house_measures_passed_total_house_joint_resolutions  \
# 100_1                                                 66
# 80_1                                                  33
#
#       legislative_activity_house_measures_passed_total_senate_concurrent_resolutions  \
# 100_1                                                  8
# 80_1                                                  10
#
#       legislative_activity_house_measures_passed_total_house_concurrent_resolutions  \
# 100_1                                                 53
# 80_1                                                  21
#
#       legislative_activity_house_measures_passed_total_simple_resolutions  \
# 100_1                                                138
# 80_1                                                 230
#
#       legislative_activity_house_measures_reported_total_total  \
# 100_1                                                426
# 80_1                                                1100
#
#       legislative_activity_house_measures_reported_total_senate_bills  \
# 100_1                                                  9
# 80_1                                                 102
#
#       legislative_activity_house_measures_reported_total_house_bills  \
# 100_1                                                299
# 80_1                                                 753
#
#       legislative_activity_house_measures_reported_total_house_joint_resolutions  \
# 100_1                                                  9
# 80_1                                                  48
#
#       legislative_activity_house_measures_reported_total_house_concurrent_resolutions  \
# 100_1                                                  7
# 80_1                                                  12
#
#       legislative_activity_house_measures_reported_total_simple_resolutions  \
# 100_1                                                102
# 80_1                                                 169
#
#       legislative_activity_house_special_reports  \
# 100_1                                         56
# 80_1                                          75
#
#       legislative_activity_house_conference_reports  \
# 100_1                                            16
# 80_1                                            NaN
#
#       legislative_activity_house_measures_pending_on_calendar  \
# 100_1                                                 48
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_total  \
# 100_1                                               4857
# 80_1                                                5658
#
#       legislative_activity_house_measures_introduced_total_bills  \
# 100_1                                               3840
# 80_1                                                4831
#
#       legislative_activity_house_measures_introduced_total_joint_resolutions  \
# 100_1                                                437
# 80_1                                                 284
#
#       legislative_activity_house_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                235
# 80_1                                                 129
#
#       legislative_activity_house_measures_introduced_total_simple_resolutions  \
# 100_1                                                345
# 80_1                                                 414
#
#       legislative_activity_house_quorum_calls  \
# 100_1                                      23
# 80_1                                       69
#
#       legislative_activity_house_yea_and_nay_votes  \
# 100_1                                          234
# 80_1                                            84
#
#       legislative_activity_house_recorded_votes  \
# 100_1                                       254
# 80_1                                        NaN
#
#       legislative_activity_house_bills_vetoed  \
# 100_1                                       2
# 80_1                                      NaN
#
#       legislative_activity_house_vetoes_overridden  \
# 100_1                                            2
# 80_1                                             1
#
#       legislative_activity_total_congressional_record_pages_of_proceedings  \
# 100_1                                              31738
# 80_1                                               11889
#
#       legislative_activity_total_congressional_record_extensions_of_remarks  \
# 100_1                                               5016
# 80_1                                                 NaN
#
#       legislative_activity_total_public_bills_enacted_into_law  \
# 100_1                                                240
# 80_1                                                 395
#
#       legislative_activity_total_private_bills_enacted_into_law  \
# 100_1                                                  7
# 80_1                                                 131
#
#       legislative_activity_total_measures_passed_total_total  \
# 100_1                                               1260
# 80_1                                                 NaN
#
#       legislative_activity_total_measures_reported_total_total  \
# 100_1                                                824
# 80_1                                                 NaN
#
#       legislative_activity_total_measures_introduced_total_total  \
# 100_1                                               7542
# 80_1                                                7970
#
#       legislative_activity_total_bills_vetoed  \
# 100_1                                       3
# 80_1                                      NaN
#
#       disposition_of_executive_nominations_start_date  \
# 100_1                        1987-01-06T05:00:00.000Z
# 80_1                         1947-01-03T05:00:00.000Z
#
#       disposition_of_executive_nominations_end_date  \
# 100_1                      1988-10-22T05:00:00.000Z
# 80_1                       1947-12-19T05:00:00.000Z
#
#       disposition_of_executive_nominations_civilian_nominees_total  \
# 100_1                                                470
# 80_1                                                1506
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_confirmed  \
# 100_1                                                331
# 80_1                                                1480
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_unconfirmed  \
# 100_1                                                112
# 80_1                                                  20
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_withdrawn  \
# 100_1                                                 10
# 80_1                                                   6
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_rejected  \
# 100_1                                                  1
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_to_white_house_1  \
# 100_1                                                  7
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_to_white_house_2  \
# 100_1                                                  9
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_total  \
# 100_1                                               4248
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_confirmed  \
# 100_1                                               4238
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_unconfirmed  \
# 100_1                                                 10
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_total  \
# 100_1                                              18667
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_confirmed  \
# 100_1                                              15711
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_unconfirmed  \
# 100_1                                               2955
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_returned_to_white_house  \
# 100_1                                                  1
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_army_nominees_total  \
# 100_1                                              14448
# 80_1                                               25863
#
#       disposition_of_executive_nominations_army_nominees_disposition_confirmed  \
# 100_1                                              12086
# 80_1                                               25568
#
#       disposition_of_executive_nominations_army_nominees_disposition_unconfirmed  \
# 100_1                                               2361
# 80_1                                                 285
#
#       disposition_of_executive_nominations_army_nominees_disposition_returned_to_white_house  \
# 100_1                                                  1
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_navy_nominees_total  \
# 100_1                                              12101
# 80_1                                               11144
#
#       disposition_of_executive_nominations_navy_nominees_disposition_confirmed  \
# 100_1                                              12055
# 80_1                                               11115
#
#       disposition_of_executive_nominations_navy_nominees_disposition_unconfirmed  \
# 100_1                                                 46
# 80_1                                                  29
#
#       disposition_of_executive_nominations_marine_corps_nominees_total  \
# 100_1                                               1995
# 80_1                                                 759
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_confirmed  \
# 100_1                                               1983
# 80_1                                                 757
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_unconfirmed  \
# 100_1                                                 10
# 80_1                                                   2
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_returned_to_white_house  \
# 100_1                                                  2
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_nominees_received_this_session  \
# 100_1                                              51929
# 80_1                                               40672
#
#       disposition_of_executive_nominations_summary_total_confirmed  \
# 100_1                                              46404
# 80_1                                               39855
#
#       disposition_of_executive_nominations_summary_total_unconfirmed  \
# 100_1                                               5494
# 80_1                                                 570
#
#       disposition_of_executive_nominations_summary_total_withdrawn  \
# 100_1                                                 10
# 80_1                                                 132
#
#       disposition_of_executive_nominations_summary_total_rejected  \
# 100_1                                                  1
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_returned_to_white_house  \
# 100_1                                                 20
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.senate.measures_reported_total.total  \
# 100_1  These figures on measures reported include all...
# 80_1   These figures on measures reported include all...
#
#       footnote_resume.legislative_activity.house.measures_reported_total.total  \
# 100_1  These figures on measures reported include all...
# 80_1   These figures on measures reported include all...
#
#       footnote_resume.disposition_of_executive_nominations.civilian_nominees.disposition.returned_to_white_house_1  \
# 100_1  Nominations returned to the President without ...
# 80_1                                                 NaN
#
#       footnote_resume.disposition_of_executive_nominations.civilian_nominees.disposition.returned_to_white_house_2  \
# 100_1  Nominations returned to the President without ...
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_reported_total_senate_joint_resolutions  \
# 100_1                                                NaN
# 80_1                                                  14
#
#       legislative_activity_house_measures_reported_total_senate_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                   2
#
#       legislative_activity_house_measures_introduced_total_field1  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_field2  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_army_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                  10
#
#       disposition_of_executive_nominations_navy_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_navy_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_marine_corps_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_congressional_record_extensions_of_remarks  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_congressional_record_extensions_of_remarks  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_bills_through_conference  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_bills_through_conference  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_bills_not_signed  \
# 100_1                                          NaN
# 80_1                                           NaN
#
#       legislative_activity_total_bills_in_conference  \
# 100_1                                            NaN
# 80_1                                             NaN
#
#       legislative_activity_total_bills_not_signed  \
# 100_1                                         NaN
# 80_1                                          NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_ajournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.senate.bills_not_signed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_marine_corps_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_returned_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_measures_reported_total_sentate_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_return_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_navy_nominees_disposition_return_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_navy_nominees_disposition_returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_recorded_votes  \
# 100_1                                        NaN
# 80_1                                         NaN
#
#       legislative_activity_senate_measures_reported_total_senate _concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_bill_in_conference  \
# 100_1                                            NaN
# 80_1                                             NaN
#
#       legislative_activity_total_public_bill_enacted_into_law  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_quorum_calls  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_yea_and_nay_votes  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_recorded_votes  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_bills_vetoed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_house_measures_introduced_total_vetoes_overridden  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_other_civilian_nominees_disposition_uncomfirmed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_space_force_nominees_total  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_space_force_nominees_disposition_confirmed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_total_public_bills_enacted_into_law_total  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_space_force_nominees_disposition_unconfirmed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_space_force_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_space_force_nominees_carried_over_from_first_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_senate_reported_measures_not_acted_on  \
# 100_1                                                NaN
# 80_1                                                  93
#
#       legislative_activity_senate_bills_vetoed_total  \
# 100_1                                            NaN
# 80_1                                               8
#
#       legislative_activity_senate_bills_vetoed_regular_vetoes  \
# 100_1                                                NaN
# 80_1                                                   6
#
#       legislative_activity_senate_bills_vetoed_pocket_vetoes  \
# 100_1                                                NaN
# 80_1                                                   2
#
#       legislative_activity_house_reported_measures_not_acted_on  \
# 100_1                                                NaN
# 80_1                                                 116
#
#       legislative_activity_house_bills_vetoed_total  \
# 100_1                                           NaN
# 80_1                                             24
#
#       legislative_activity_house_bills_vetoed_regular_vetoes  \
# 100_1                                                NaN
# 80_1                                                   7
#
#       legislative_activity_house_bills_vetoed_pocket_vetoes  \
# 100_1                                                NaN
# 80_1                                                  17
#
#       legislative_activity_total_congressional_record_appendix  \
# 100_1                                                NaN
# 80_1                                                5302
#
#       legislative_activity_total_bill_in_conference  \
# 100_1                                           NaN
# 80_1                                              4
#
#       legislative_activity_total_bills_through_conference  \
# 100_1                                                NaN
# 80_1                                                  62
#
#       legislative_activity_total_measures_passed_total_simple_resolutions  \
# 100_1                                                NaN
# 80_1                                                 317
#
#       legislative_activity_total_measures_reported_total_simple_resolutions  \
# 100_1                                                NaN
# 80_1                                                 264
#
#       legislative_activity_total_conference_reports  \
# 100_1                                           NaN
# 80_1                                             59
#
#       legislative_activity_total_measures_introduced_total_bills  \
# 100_1                                                NaN
# 80_1                                                6755
#
#       legislative_activity_total_measures_introduced_total_joint_resolutions  \
# 100_1                                                NaN
# 80_1                                                 454
#
#       legislative_activity_total_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 166
#
#       legislative_activity_total_measures_introduced_total_simple_resolutions  \
# 100_1                                                NaN
# 80_1                                                 595
#
#       legislative_activity_total_quorum_calls  \
# 100_1                                     NaN
# 80_1                                      401
#
#       legislative_activity_total_yea_and_nay_votes  \
# 100_1                                          NaN
# 80_1                                           222
#
#       legislative_activity_total_bills_vetoed_total  \
# 100_1                                           NaN
# 80_1                                             32
#
#       legislative_activity_total_bills_vetoed_regular_vetoes  \
# 100_1                                                NaN
# 80_1                                                  13
#
#       legislative_activity_total_bills_vetoed_pocket_vetoes  \
# 100_1                                                NaN
# 80_1                                                  19
#
#       legislative_activity_total_vetoes_overridden  \
# 100_1                                          NaN
# 80_1                                             1
#
#       disposition_of_executive_nominations_postmaster_nominees_total  \
# 100_1                                                NaN
# 80_1                                                1285
#
#       disposition_of_executive_nominations_postmaster_nominees_disposition_confirmed  \
# 100_1                                                NaN
# 80_1                                                 935
#
#       disposition_of_executive_nominations_postmaster_nominees_disposition_withdrawn  \
# 100_1                                                NaN
# 80_1                                                 116
#
#       disposition_of_executive_nominations_postmaster_nominees_disposition_unconfirmed  \
# 100_1                                                NaN
# 80_1                                                 234
#
#       footnote_resume.legislative_activity.senate.reported_measures_not_acted_on  \
# 100_1                                                NaN
# 80_1   This figure does not agree with the total diff...
#
#       footnote_resume.legislative_activity.house.reported_measures_not_acted_on  \
# 100_1                                                NaN
# 80_1   This figure does not agree with the total diff...
#
#       legislative_activity_senate_regular_vetoes  \
# 100_1                                        NaN
# 80_1                                         NaN
#
#       legislative_activity_senate_pocket_vetoes  \
# 100_1                                       NaN
# 80_1                                        NaN
#
#       legislative_activity_house_regular_vetoes  \
# 100_1                                       NaN
# 80_1                                        NaN
#
#       legislative_activity_house_pocket_vetoes  \
# 100_1                                      NaN
# 80_1                                       NaN
#
#       legislative_activity_total_regular_vetoes  \
# 100_1                                       NaN
# 80_1                                        NaN
#
#       legislative_activity_total_pocket_vetoes  \
# 100_1                                      NaN
# 80_1                                       NaN
#
#       legislative_activity_senate_measures_passed_total_bills  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_total_measures_passed_total_senate_bills  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
# ...
# 100_1                            NaN                               NaN
# 80_1                             NaN                               NaN
#
#       house_measures_passed_total_senate_bills  \
# 100_1                                      NaN
# 80_1                                       NaN
#
#       house_measures_passed_total_house_bills  \
# 100_1                                     NaN
# 80_1                                      NaN
#
#       house_measures_passed_total_senate_joint_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_passed_total_house_joint_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_passed_total_senate_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_passed_total_house_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_passed_total_simple_resolutions  \
# 100_1                                            NaN
# 80_1                                             NaN
#
#       house_measures_reported_total_total  \
# 100_1                                 NaN
# 80_1                                  NaN
#
#       house_measures_reported_total_senate_bills  \
# 100_1                                        NaN
# 80_1                                         NaN
#
#       house_measures_reported_total_house_bills  \
# 100_1                                       NaN
# 80_1                                        NaN
#
#       house_measures_reported_total_senate_joint_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_reported_total_house_joint_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_reported_total_senate_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_reported_total_house_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_reported_total_simple_resolutions house_special_reports  \
# 100_1                                              NaN                   NaN
# 80_1                                               NaN                   NaN
#
#       house_reported_measures_not_acted_on  \
# 100_1                                  NaN
# 80_1                                   NaN
#
#       house_measures_introduced_total_total  \
# 100_1                                   NaN
# 80_1                                    NaN
#
#       house_measures_introduced_total_bills  \
# 100_1                                   NaN
# 80_1                                    NaN
#
#       house_measures_introduced_total_joint_resolutions  \
# 100_1                                               NaN
# 80_1                                                NaN
#
#       house_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       house_measures_introduced_total_simple_resolutions house_quorum_calls  \
# 100_1                                                NaN                NaN
# 80_1                                                 NaN                NaN
#
#       house_yea_and_nay_votes house_bills_vetoed  \
# 100_1                     NaN                NaN
# 80_1                      NaN                NaN
#
#       total_congressional_record_pages_of_proceedings  \
# 100_1                                             NaN
# 80_1                                              NaN
#
#       total_congressional_record_appendix total_public_bills_enacted_into_law  \
# 100_1                                 NaN                                 NaN
# 80_1                                  NaN                                 NaN
#
#       total_private_bills_enacted_into_law  \
# 100_1                                  NaN
# 80_1                                   NaN
#
#       total_measures_passed_total_simple_resolutions  \
# 100_1                                            NaN
# 80_1                                             NaN
#
#       total_measures_reported_total_simple_resolutions  \
# 100_1                                              NaN
# 80_1                                               NaN
#
#       total_measures_introduced_total_total  \
# 100_1                                   NaN
# 80_1                                    NaN
#
#       total_measures_introduced_total_bills  \
# 100_1                                   NaN
# 80_1                                    NaN
#
#       total_measures_introduced_total_joint_resolutions  \
# 100_1                                               NaN
# 80_1                                                NaN
#
#       total_measures_introduced_total_concurrent_resolutions  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       total_measures_introduced_total_simple_resolutions total_quorum_calls  \
# 100_1                                                NaN                NaN
# 80_1                                                 NaN                NaN
#
#       total_yea_and_nay_votes  \
# 100_1                     NaN
# 80_1                      NaN
#
#       legislative_activity_total_reported_measures_not_acted_on  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.senate.quorum_calls  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.senate.yea_and_nay_votes  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.army_nominees.disposition.returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.navy_nominees.disposition.returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.civilian_nominees.disposition.returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.legislative_activity.disposition_of_executive_nominations.summary.total_returned_to_white_house  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.disposition_of_executive_nominations.civilian_nominees.disposition.unconfirmed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       footnote_resume.disposition_of_executive_nominations.summary.total_nominees_received_this_session  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_congressional_record_pages_of_proceedings  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_congressional_record_extensions_of_remarks  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_public_bills_enacted_into_law  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_private_bills_enacted_into_law  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       legislative_activity_bills_in_conference  \
# 100_1                                      NaN
# 80_1                                       NaN
#
#       legislative_activity_bills_through_conference  \
# 100_1                                           NaN
# 80_1                                            NaN
#
#       legislative_activity_house_start_date  \
# 100_1                                   NaN
# 80_1                                    NaN
#
#       legislative_activity_house_end_date  \
# 100_1                                 NaN
# 80_1                                  NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_superseded_by_renominations_confirmations  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_of_confirmation_ontime  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_of_confirmation_ontime  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_superseded_by_renominations_confirmations  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_failed_at_first_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_army_nominees_disposition_failed_at_second_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_air_force_nominees_disposition_failed  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_first_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_at_second_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_first_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_at_second_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_recess_appointments  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_recess_appointments  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_of_confirmation_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_failed_of_confirmation_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_civilian_nominees_disposition_superceded_by_recess_appointment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_of_confirmation_at_aug_sept_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_failed_of_confirmation_at_sine_die_adjournment  \
# 100_1                                                NaN
# 80_1                                                 NaN
#
#       disposition_of_executive_nominations_summary_total_superseded_by_recess_appointment
# 100_1                                                NaN
# 80_1                                                 NaN

# %%
def print_empty_cells():
    empty_cells = df.isnull().stack()
    empty_index = empty_cells[empty_cells].index.tolist()

    for idx in empty_index:
        row, col = idx
        print(f"{row};;;{col}")

# %%
def filter_df(input_df):
    df_filtered = input_df[[col for col in input_df if not col.startswith("footnote")]]
    df_filtered = df_filtered[[col for col in df_filtered if not col.startswith("url")]]
    return df_filtered

# %%
def split_df(input_df):
    activity = input_df[[col for col in input_df if col.startswith("legislative_activity") or col == "congress" or col == "session" or col == "report_date"]]
    disposition = input_df[[col for col in input_df if col.startswith("disposition") or col == "congress" or col == "session" or col == "report_date"]]
    return activity, disposition
    
def save_to_pickle(input_df):
    df = filter_df(input_df)
    activity, disposition = split_df(df)
    activity.to_pickle('activity.pkl')
    disposition.to_pickle('disposition.pkl')

save_to_pickle(df)
